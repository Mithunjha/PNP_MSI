# %%
# !python training.py --epochs 3
# Out:
# Device: cuda
# experiment_name : Denoising
# batch_size : 16
# N : 192
# epochs : 3
# lr : 0.001
# gamma : 0.3
# seed : 42
# noise_level_range : [0.01, 0.2]
# use_gpu : True
# data_directory : C:/Users/ma127/Mithunjha/deep_equilibrium_inverse/dataset
# save_path : C:/Users/ma127/Mithunjha/PNP_MSI/test
# Reading from C:/Users/ma127/Mithunjha/deep_equilibrium_inverse/dataset\processed_data_R00.npy ====================================================
# Shape of the data : (176, 192, 320)
# Reading from C:/Users/ma127/Mithunjha/deep_equilibrium_inverse/dataset\processed_data_R01.npy ====================================================
# Shape of the data : (355, 192, 320)
# Reading from C:/Users/ma127/Mithunjha/deep_equilibrium_inverse/dataset\processed_data_R02.npy ====================================================
# Shape of the data : (533, 192, 320)
# ...

# %%
# !python run.py
# Out:
# sampling_percentage : 50
# experiment_name : FT-ICR_simulated
# model_path : C:/Users/ma127/Mithunjha/PNP_MSI/test/best_model.pth.tar
# max_iteration : 20
# N : 192
# noise_level : 0.01
# use_gpu : True
# rho : 0.001
# tol : 1e-08
# data_path : C:/Users/ma127/Mithunjha/deep_equilibrium_inverse/dataset
# seed : 42
# save_path : C:/Users/ma127/Mithunjha/PNP_MSI/
# ROI : R05
# id : 21
# Device: cuda
# Project directory available at C:/Users/ma127/Mithunjha/PNP_MSI/FT-ICR_simulated/PNP_ADMM_rho_0.001_noise_0.01_max_iter_20_N_192
# (192, 192)
# (192, 192) (192, 192) (192, 192)
# Figure(2000x500)
# Figure(800x400)
# Figure(640x480)
# PSNR (Input) = 40.86893, SSIM (Input) = 0.98744, MSE (Input) = 5.32338,
# PSNR (Cubic Interpolation) = 40.71832, SSIM (Cubic Interpolation) = 0.98730, MSE (Cubic Interpolation) = 5.51123,
# PSNR (PNP ADMM) = 40.90339, SSIM (PNP ADMM) = 0.98751, MSE (PNP ADMM) = 5.28130,
